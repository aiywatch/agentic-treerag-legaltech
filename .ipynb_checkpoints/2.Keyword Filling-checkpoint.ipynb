# %%
GITHUB_URL = "https://models.github.ai/inference"
OPENROUTER_URL = "https://openrouter.ai/api/v1"

# %%
import os
from dotenv import load_dotenv

# โหลดค่าจากไฟล์ .env
load_dotenv()

# ดึงค่ามาใช้
GROQ_API_KEY = os.getenv("GROQ_KEY")
OPENROUTER_KEY = os.getenv("OPENROUTER_KEY")
GITHUB_KEY = os.getenv("GITHUB_KEY")

# %% [markdown]
# ## FILE PATHS

# %%
SEC_JSON_PATH = 'intemediate_data/sec_reg_structured.json'
SEC_W_KW_PATH = 'intemediate_data/sec_reg_tree_enhanced.json'
# QUESTION_JSON_PATH = 'questions/eval_questions2.json'
# TREERAG_RESULT_PATH = 'results/legaltreerag_ans.csv'

# %% [markdown]
# ## LLM MODELS

# %%
# KEYWORD_EXTRACTION_MODEL = "llama-3.1-8b-instant"
# KEYWORD_EXTRACTION_MODEL = "openai/gpt-oss-120b"
KEYWORD_EXTRACTION_MODEL = "llama-3.3-70b-versatile"

# KEYWORD_EXTRACTION_MODEL = "openai/gpt-oss-120b:free"

# %%
# llm_model_retrieve = "openai/gpt-4.1"
# llm_model_ans = "openai/gpt-4.1-mini"
# llm_model_ans = "openai/gpt-4.1"

# llm_model_retrieve = "deepseek/deepseek-r1"
# llm_model_ans = "deepseek/deepseek-v3"

# llm_model_retrieve = "Llama-3.3-70B-Instruct"
# llm_model_ans = "meta/llama-3.3-70b-instruct"



# llm_model_retrieve = "llama-3.3-70b-versatile"
# llm_model_retrieve = "openai/gpt-oss-safeguard-20b"
# llm_model_retrieve = "openai/gpt-oss-120b"
# llm_model_ans = "meta-llama/llama-4-scout-17b-16e-instruct"

# llm_model_retrieve = "llama-3.1-8b-instant"
# llm_model_ans = 'openai/gpt-oss-120b'
# llm_model_ans = "qwen/qwen3-32b"

# %%
# from openai import OpenAI
# import json
# import re

# client = OpenAI(base_url=OPENROUTER__MODEL_URL, api_key=OPENROUTER_KEY,)
# client = OpenAI(base_url=GITHUB_MODEL_URL, api_key=GITHUB_KEY)

# %%
from groq import Groq

os.environ["GROQ_API_KEY"] = GROQ_KEY
client = Groq()

# %% [markdown]
# ## Phase 1.1 : Using LLM to add Keywords to each nodes

# %%
import json
import time
import re


# โหลดข้อมูล
try:
    with open(SEC_JSON_PATH, 'r', encoding='utf-8') as f:
        reg_data = json.load(f)
except FileNotFoundError:
    print(f"❌ ไม่พบไฟล์ {SEC_JSON_PATH} กรุณาตรวจสอบชื่อไฟล์อีกครั้ง")
    exit()

# ---------------------------------------------------------
# 1. ฟังก์ชันช่วย: กำหนด ID แบบ Hierarchical
# ---------------------------------------------------------
def assign_node_ids(nodes, parent_id="root"):
    for i, node in enumerate(nodes):
        current_id = f"{parent_id}_{i}"
        node['node_id'] = current_id
        if 'subsection' in node and len(node['subsection']) > 0:
            assign_node_ids(node['subsection'], current_id)

# ---------------------------------------------------------
# 2. ค้นหาและรวบรวม Node ที่ต้องทำ Keyword ลง List
# ---------------------------------------------------------
target_nodes = []
target_levels = ['ภาค', 'หมวด', 'ข้อ', 'ส่วนนำ', 'ส่วน', "คำศัพท์"]

def collect_target_nodes(nodes):
    for node in nodes:
        if node.get('section_type') in target_levels:
            target_nodes.append(node)
        if 'subsection' in node and len(node['subsection']) > 0:
            collect_target_nodes(node['subsection'])

# ---------------------------------------------------------
# 3. ฟังก์ชันหลัก: เรียก LLM แบบมัดรวม (Batch Processing) พร้อมระบบ Retry
# ---------------------------------------------------------
def process_keywords_in_batches(node_list, batch_size=10): 
    total_nodes = len(node_list)
    print(f"📦 พบหัวข้อที่ต้องสกัด Keyword ทั้งหมด {total_nodes} ข้อ (แบ่งทำทีละ {batch_size} ข้อ)")
    
    for i in range(0, total_nodes, batch_size):
        batch = node_list[i:i+batch_size]
        print(f"\n⏳ กำลังสกัด Keyword ชุดที่ {i//batch_size + 1} (ข้อ {i+1} ถึง {min(i+batch_size, total_nodes)})...")
        
        # 1. ดึง ID ทั้งหมดใน Batch นี้เพื่อเอาไปบังคับ LLM
        batch_ids = [node['node_id'] for node in batch]
        
        prompt_text = "จงสกัด Keyword สำคัญทางกฎหมาย 8-15 คำ ของแต่ละหัวข้อต่อไปนี้ โดยต้องครอบคลุมถึงรายละเอียดในข้อย่อยด้วย:\n\n"
        for node in batch:
            node_id = node['node_id']
            section = node.get('section', '')
            raw_content = node.get('raw', node.get('description', ''))
            content_to_use = " ".join(raw_content.split())[:2000] 
            
            prompt_text += f"ID: {node_id}\nหัวข้อ: {section}\nเนื้อหา: {content_to_use}\n---\n"
            
        prompt_text += f"""
คำสั่งและข้อบังคับ: 
1. ให้ตอบกลับเป็น JSON Object เท่านั้น โดยใช้ ID เป็น Key และ Keyword เป็น Value
2. Keyword ต้องประกอบด้วย "คำนามเฉพาะ", "ชื่อกลุ่มเป้าหมาย (เช่น ผู้ลงทุนสถาบัน, PP10)", และ "เงื่อนไขสำคัญ (เช่น ปรับโครงสร้างหนี้)" ที่ซ่อนอยู่ในข้อย่อยต่างๆ
3. ห้ามใช้คำกริยากว้างๆ คำเดียว และต้องสกัดให้ครอบคลุมเนื้อหาสำคัญทั้งหมดที่ปรากฏในข้อนั้น
4. **สำคัญมาก: คุณต้องสร้าง Key สำหรับ ID เหล่านี้ให้ครบทุกตัว ห้ามข้ามเด็ดขาด:**
{batch_ids}

ตัวอย่างรูปแบบการตอบ (ต้องมีครบทุก ID ที่ให้ไป):
{{
    "{batch_ids[0] if len(batch_ids) > 0 else 'root_1_0'}": "keyword1, keyword2, keyword3...",
    "{batch_ids[1] if len(batch_ids) > 1 else 'root_1_1'}": "keyword1, keyword2, keyword3..."
}}
"""
        
        # 📌 ระบบป้องกันความผิดพลาด (Retry Logic)
        MAX_RETRIES = 3 # ให้โอกาสโมเดลแก้ตัว 3 รอบ
        for attempt in range(MAX_RETRIES):
            try:
                response = client.chat.completions.create(
                    messages=[{"role": "user", "content": prompt_text}],
                    # model="llama-3.1-8b-instant", # แนะนำให้เปลี่ยนเป็นโมเดลที่เสถียรที่สุดที่คุณมีโควต้า
                    model=KEYWORD_EXTRACTION_MODEL,
                    temperature=0.0, # บังคับ 0 เพื่อไม่ให้โมเดลคิดอะไรนอกกรอบ
                    response_format={"type": "json_object"}
                )
                
                result_json = json.loads(response.choices[0].message.content.strip())
                
                # เช็คว่ามี ID ไหนที่ส่งไปแล้วไม่ได้ตอบกลับมาบ้าง
                missing_keys = [node['node_id'] for node in batch if node['node_id'] not in result_json]
                
                if missing_keys:
                    print(f"  ⚠️ [Warning] Attempt {attempt + 1}: โมเดลลืมตอบ Keys เหล่านี้: {missing_keys}")
                    if attempt < MAX_RETRIES - 1:
                        print("  🔄 กำลังส่งคำสั่งเพื่อลองใหม่...")
                        time.sleep(2) # พัก API เล็กน้อยก่อนยิงซ้ำ
                        continue # วนลูปกลับไปยิง API ใหม่
                    else:
                        print("  ❌ พยายามครบโควต้าแล้ว ข้าม Keys ที่หายไป")
                
                # หากดึงข้อมูลสำเร็จ หรือพยายามครบทุกรอบแล้ว ให้นำผลลัพธ์ไปใส่ใน Node
                for node in batch:
                    node_id = node['node_id']
                    # ใช้ .get() เพื่อป้องกัน Error หากสุดท้าย Key ก็ยังหายอยู่ดี
                    node['keywords'] = result_json.get(node_id, "")
                    print(node_id, node['keywords'])
                
                print(f"  ✅ สำเร็จ!")
                break # ได้ผลลัพธ์ครบ จบการทำงานของ Attempt Loop นี้ เพื่อไปทำ Batch ถัดไป
                
            except Exception as e:
                print(f"  ⚠️ [Error] ชุดที่ {i//batch_size + 1} ล้มเหลว (Attempt {attempt+1}): {e}")
                if attempt == MAX_RETRIES - 1:
                    print("  ❌ พยายามครบโควต้าแล้ว บังคับให้ Keyword เป็นค่าว่าง")
                    for node in batch:
                        node['keywords'] = "" 
                time.sleep(3) # พักก่อนลองใหม่ กรณี API ล่ม

        # time.sleep(1) # ปลดคอมเมนต์บรรทัดนี้ได้หากติด Rate Limit ของ Groq

# ---------------------------------------------------------
# 4. เริ่มรันการทำงาน
# ---------------------------------------------------------
print("🚀 สเต็ป 1: กำหนด Node ID ให้ทั้งหมด...")
assign_node_ids(reg_data['data'])

print("🚀 สเต็ป 2: รวบรวมหัวข้อที่ต้องการ...")
collect_target_nodes(reg_data['data'])

print("🚀 สเต็ป 3: ส่ง LLM สกัด Keyword แบบ Batch...")
# แนะนำ Batch Size ประมาณ 20-30 กำลังดี ไม่ให้ Token ขาออกล้นเกินไป
# process_keywords_in_batches(target_nodes, batch_size=12) 
process_keywords_in_batches(target_nodes, batch_size=10)

# บันทึกไฟล์
with open(SEC_W_KW_PATH, 'w', encoding='utf-8') as f:
    json.dump(reg_data, f, ensure_ascii=False, indent=4)

print(f"\n🎉 สำเร็จ! บันทึกไฟล์ Tree แบบ Fast-Batch (จาก Raw Text) ลงใน '{output_filename}' เรียบร้อยแล้ว!\n")
# Out:
# 🚀 สเต็ป 1: กำหนด Node ID ให้ทั้งหมด...
# 🚀 สเต็ป 2: รวบรวมหัวข้อที่ต้องการ...
# 🚀 สเต็ป 3: ส่ง LLM สกัด Keyword แบบ Batch...
# 📦 พบหัวข้อที่ต้องสกัด Keyword ทั้งหมด 222 ข้อ (แบ่งทำทีละ 10 ข้อ)
#
# ⏳ กำลังสกัด Keyword ชุดที่ 1 (ข้อ 1 ถึง 10)...
# root_0_0 พระราชบัญญัติหลักทรัพย์และตลาดหลักทรัพย์, ผู้ออกหลักทรัพย์, ผู้ลงทุน, การออกและเสนอขายตราสารหนี้
# root_0_1 วันที่ใช้บังคับ, วันที่ 1 ตุลาคม พ.ศ. 2565, ผู้ออกหลักทรัพย์, ผู้ลงทุน
# root_0_2 การกำหนดบทนิยาม, ตราสารหนี้, กองทรัสต์, หุ้นกู้แปลงสภาพ, ผู้ออกหลักทรัพย์, ผู้ลงทุน
# root_0_2_0 การกำหนดบทนิยาม, ตราสารหนี้, กองทรัสต์, หุ้นกู้แปลงสภาพ, ผู้ออกหลักทรัพย์, ผู้ลงทุน
# root_0_2_1 ตราสารหนี้, หุ้นกู้, พันธบัตร, ตั๋วเงิน, ผู้ออกหลักทรัพย์, ผู้ลงทุน
# root_0_2_1_0 ตราสารหนี้, หุ้นกู้, พันธบัตร, ตั๋วเงิน, ผู้ออกหลักทรัพย์, ผู้ลงทุน
# root_0_2_2 กองทรัสต์, ทรัสต์เพื่อการลงทุนในอสังหาริมทรัพย์, ทรัสต์เพื่อการลงทุนในโครงสร้างพื้นฐาน, ผู้ออกหลักทรัพย์, ผู้ลงทุน
# root_0_2_2_0 กองทรัสต์, ทรัสต์เพื่อการลงทุนในอสังหาริมทรัพย์, ทรัสต์เพื่อการลงทุนในโครงสร้างพื้นฐาน, ผู้ออกหลักทรัพย์, ผู้ลงทุน
# root_0_2_3 หุ้นกู้แปลงสภาพ, หุ้นออกใหม่, ผู้ออกหุ้นกู้แปลงสภาพ, ผู้ลงทุน
# root_0_2_4 หุ้นรองรับ, หุ้นออกใหม่, การแปลงสภาพ, ผู้ออกหลักทรัพย์, ผู้ลงทุน
#   ✅ สำเร็จ!
#
# ⏳ กำลังสกัด Keyword ชุดที่ 2 (ข้อ 11 ถึง 20)...
# root_0_2_5 หุ้นกู้ด้อยสิทธิ, ผู้ถือหุ้นกู้, สิทธิของผู้ถือหุ้นกู้, เจ้าหนี้สามัญทั่วไป
# root_0_2_6 ข้อกำหนดสิทธิ, สิทธิของผู้ออกตราสาร, หน้าที่ของผู้ออกตราสาร, สิทธิของผู้ถือตราสาร
# root_0_2_7 สมาคมตลาดตราสารหนี้ไทย, ใบอนุญาต, จดทะเบียน, สำนักงาน
# root_0_2_8 ตลาดหลักทรัพย์, ตลาดหลักทรัพย์แห่งประเทศไทย
# root_0_2_9 ผู้บริหาร, ตำแหน่งบริหารสูงสุด, ผู้จัดการฝ่าย, สายงานบัญชี, สายงานการเงิน
# root_0_2_9_0 ผู้บริหาร, ตำแหน่งบริหารสูงสุด, ผู้จัดการฝ่าย, สายงานบัญชี, สายงานการเงิน
# root_0_2_10 ที่ปรึกษาทางการเงิน, สำนักงาน, ความเห็นชอบ
# root_1 ภาค 1, บททั่วไป, ขอบเขตของประกาศ, หลักเกณฑ์ทั่วไป, การขออนุญาต, การอนุญาต, การเสนอขายตราสารหนี้, การเสนอขายหุ้นกู้แปลงสภาพ
# root_1_0 ภาค 1, บททั่วไป
# root_1_1 หมวด 1, ขอบเขตของประกาศ, หลักเกณฑ์ทั่วไป, การขออนุญาต, การอนุญาต, การเสนอขายตราสารหนี้, การเสนอขายหุ้นกู้แปลงสภาพ, กิจการไทย, กิจการต่างประเทศ, หน่วยงานภาครัฐไทย, กองทรัสต์
#   ✅ สำเร็จ!
#
# ⏳ กำลังสกัด Keyword ชุดที่ 3 (ข้อ 21 ถึง 30)...
# root_1_1_0 การขออนุญาต, การอนุญาต, ตราสารหนี้, หุ้นกู้แปลงสภาพ, กิจการไทย, กิจการต่างประเทศ, หน่วยงานภาครัฐไทย, กองทรัสต์
# root_1_1_1 การขออนุญาต, การอนุญาต, ตราสารหนี้, หุ้นกู้แปลงสภาพ, กิจการไทย, บริษัทจำกัด, บริษัทมหาชนจำกัด, สาขาธนาคารพาณิชย์ต่างประเทศ, หน่วยงานหรือองค์การของรัฐบาลต่างประเทศ, องค์การระหว่างประเทศ, นิติบุคคล, กองทรัสต์
# root_1_1_1_0 การขออนุญาต, การอนุญาต, ตราสารหนี้, หุ้นกู้แปลงสภาพ, กิจการไทย, บริษัทจำกัด, บริษัทมหาชนจำกัด, กองทรัสต์
# root_1_1_1_1_0 กิจการไทย, บริษัทจำกัด, บริษัทมหาชนจำกัด, สาขาธนาคารพาณิชย์ต่างประเทศ
# root_1_1_1_2_0 กิจการต่างประเทศ, หน่วยงานหรือองค์การของรัฐบาลต่างประเทศ, องค์การระหว่างประเทศ, นิติบุคคล
# root_1_1_1_3_0 หน่วยงานภาครัฐไทย, องค์การมหาชน, องค์การบริหารส่วนจังหวัด, เทศบาล, กรุงเทพมหานคร, เมืองพัทยา, องค์กรปกครองส่วนท้องถิ่น, นิติบุคคล
# root_1_1_2 การเสนอขายหุ้นกู้แปลงสภาพ, ผู้ถือหุ้น, บริษัทจดทะเบียน, บริษัทมหาชนจำกัด, เจ้าหนี้, แผนฟื้นฟูกิจการ
# root_1_1_2_0 การเสนอขายหุ้นกู้แปลงสภาพ, ผู้ถือหุ้น, บริษัทจดทะเบียน, บริษัทมหาชนจำกัด, เจ้าหนี้
# root_1_1_3 การขออนุญาต, การอนุญาต, ตราสารหนี้, หุ้นกู้แปลงสภาพ, กรรมการ, พนักงาน, ผู้ลงทุน, ต่างประเทศ
# root_1_1_3_0 การขออนุญาต, การอนุญาต, ตราสารหนี้, หุ้นกู้แปลงสภาพ, กรรมการ, พนักงาน, ผู้ลงทุน
#   ✅ สำเร็จ!
#
# ⏳ กำลังสกัด Keyword ชุดที่ 4 (ข้อ 31 ถึง 40)...
# root_1_1_3_3_0 การขออนุญาต, การอนุญาต, ตราสารหนี้สกุลเงินตราต่างประเทศ, ผู้ลงทุนในต่างประเทศ, หลักเกณฑ์การขออนุญาต
# root_1_1_4 การอนุญาต, การเสนอขายตราสารหนี้, ลักษณะการเสนอขาย, วงจำกัด, การเสนอขายหุ้นกู้แปลงสภาพ
# root_1_1_4_0 การอนุญาต, การเสนอขายตราสารหนี้, หลักเกณฑ์การอนุญาต
# root_1_2 การยื่นข้อมูล, สำนักงาน, หลักเกณฑ์การยื่นข้อมูล, เว็บไซต์ของสำนักงาน
# root_1_2_0 การยื่นข้อมูล, สำนักงาน
# root_1_2_1 การยื่นข้อมูล, สำนักงาน, หลักเกณฑ์การยื่นข้อมูล, เว็บไซต์ของสำนักงาน
# root_1_3 อำนาจสำนักงาน, การสั่งการ, การอนุญาต, การเสนอขายตราสารหนี้, ผู้ลงทุน
# root_1_3_0 อำนาจสำนักงาน
# root_1_3_1 อำนาจสำนักงาน, การสั่งการ, การอนุญาต, การเสนอขายตราสารหนี้, ผู้ลงทุน, การผ่อนผัน
# root_1_3_1_0 อำนาจสำนักงาน, การสั่งการ
#   ✅ สำเร็จ!
#
# ⏳ กำลังสกัด Keyword ชุดที่ 5 (ข้อ 41 ถึง 50)...
# root_1_3_1_1 สำนักงานหลักทรัพย์และตลาดหลักทรัพย์, ผู้ขออนุญาต, ผู้ลงทุน, การเสนอขายตราสารหนี้, หลีกเลี่ยงกฎเกณฑ์, นโยบายสาธารณะ, ความน่าเชื่อถือ, ตลาดทุนไทย
# root_1_3_1_1_0 สำนักงานหลักทรัพย์และตลาดหลักทรัพย์, การเสนอขายตราสารหนี้, ผู้ขออนุญาต
# root_1_3_1_2 สำนักงานหลักทรัพย์และตลาดหลักทรัพย์, ผู้ขออนุญาต, การผ่อนผัน, หลักเกณฑ์, เงื่อนไข, ผู้ลงทุน, มาตรการคุ้มครอง
# root_1_3_1_2_0 สำนักงานหลักทรัพย์และตลาดหลักทรัพย์, การผ่อนผัน, ผู้ขออนุญาต
# root_1_3_1_3 สำนักงานหลักทรัพย์และตลาดหลักทรัพย์, การเสนอขายตราสารหนี้, บริษัทจดทะเบียน, ผู้ลงทุน, การระงับการเสนอขาย, การเพิกถอนการอนุญาต
# root_1_3_1_3_0 สำนักงานหลักทรัพย์และตลาดหลักทรัพย์, การเสนอขายตราสารหนี้, การระงับการเสนอขาย, การเพิกถอนการอนุญาต
# root_1_3_1_4 บริษัทจดทะเบียน, หุ้นกู้แปลงสภาพ, หุ้นรองรับ, ผู้ลงทุน, การยกเลิกการอนุญาต
# root_1_3_1_5 ผู้ขออนุญาต, การกำหนดระยะเวลา, การกำหนดเงื่อนไข, ผู้ลงทุน, มาตรการคุ้มครอง
# root_1_3_2 สำนักงานหลักทรัพย์และตลาดหลักทรัพย์, การสั่งการ, การเปลี่ยนแปลงข้อเท็จจริง, ผู้ได้รับอนุญาต, การระงับการเสนอขาย, การเพิกถอนการอนุญาต
# root_1_3_2_0 สำนักงานหลักทรัพย์และตลาดหลักทรัพย์, การสั่งการ, การเปลี่ยนแปลงข้อเท็จจริง
#   ✅ สำเร็จ!
#
# ⏳ กำลังสกัด Keyword ชุดที่ 6 (ข้อ 51 ถึง 60)...
# root_1_3_2_1 สำนักงาน, ผู้ได้รับอนุญาต, กรรมการ, ผู้บริหาร, ตราสารหนี้, การอนุญาต, การเสนอขาย, การชี้แจง, การระงับ, การเพิกถอน
# root_1_3_2_1_0 สำนักงาน, ผู้ได้รับอนุญาต, ตราสารหนี้, การอนุญาต, การเสนอขาย, การชี้แจง, การระงับ
# root_1_3_2_2 สำนักงาน, ผู้ได้รับอนุญาต, ตราสารหนี้, การอนุญาต, การเสนอขาย, การระงับ, การเพิกถอน, คุณสมบัติ, เงื่อนไข
# root_2 ตราสารหนี้, การเสนอขาย, วงจำกัด, หุ้นกู้, พันธบัตร, ตั๋วเงิน, ผู้ลงทุนสถาบัน, ผู้ลงทุนรายใหญ่พิเศษ, ผู้ลงทุนรายใหญ่
# root_2_0 ตราสารหนี้, การเสนอขาย, วงจำกัด, หุ้นกู้, พันธบัตร, ตั๋วเงิน
# root_2_1 ตราสารหนี้, การเสนอขาย, วงจำกัด, หุ้นกู้, พันธบัตร, ตั๋วเงิน, ผู้ลงทุนสถาบัน, ผู้ลงทุนรายใหญ่พิเศษ, ผู้ลงทุนรายใหญ่, PP10
# root_2_1_0 ตราสารหนี้, การเสนอขาย, วงจำกัด, หุ้นกู้, พันธบัตร, ตั๋วเงิน
# root_2_1_6_0 การเสนอขาย, ผ่อนผัน, สำนักงาน, หุ้นกู้, พันธบัตร, มาตรการ, การคุ้มครอง
# root_2_1_7_0 ตั๋วเงิน, การเสนอขาย, มูลค่า, ผู้ลงทุนสถาบัน, ผู้ลงทุนรายใหญ่พิเศษ, ผู้ลงทุนรายใหญ่
# root_2_2 การเสนอขาย, วงจำกัด, หลักเกณฑ์, การพิจารณา, การโอน, ผู้ลงทุนรายใหญ่พิเศษ, ผู้ลงทุนรายใหญ่, ผู้ลงทุนสถาบัน
#   ✅ สำเร็จ!
#
# ⏳ กำลังสกัด Keyword ชุดที่ 7 (ข้อ 61 ถึง 70)...
# root_2_2_0 การเสนอขายในวงจำกัด, การพิจารณา, หลักเกณฑ์
# root_3 การเสนอขายตราสารหนี้, วงจำกัด, ผู้ลงทุนสถาบัน, PP10, ปรับโครงสร้างหนี้
# root_3_0 การเสนอขายตราสารหนี้, วงจำกัด, ผู้ลงทุนสถาบัน, PP10, ปรับโครงสร้างหนี้
# root_3_0_0 การเสนอขายตราสารหนี้, วงจำกัด, ผู้ลงทุนสถาบัน, PP10
# root_3_0_4_0 การเสนอขายหุ้นกู้, พันธบัตร, ผู้ลงทุนสถาบัน, ผู้ลงทุนรายใหญ่พิเศษ
# root_3_1 การอนุญาต, การออกตราสารหนี้, หลักเกณฑ์ทั่วไป, ผู้ลงทุนสถาบัน
# root_3_1_0 การอนุญาต, การออกตราสารหนี้, หลักเกณฑ์ทั่วไป, ผู้ลงทุนสถาบัน
# root_3_1_0_0 การอนุญาต, การออกตราสารหนี้, หลักเกณฑ์ทั่วไป
# root_3_1_0_2_0 การออกตราสารหนี้, หลักเกณฑ์ทั่วไป, ผู้ลงทุนสถาบัน, ผู้ลงทุนรายใหญ่พิเศษ
# root_3_1_1 การออกตราสารหนี้, หลักเกณฑ์ทั่วไป, ผู้ลงทุนสถาบัน, บริษัทจำกัด, บริษัทมหาชนจำกัด
#   ✅ สำเร็จ!
#
# ⏳ กำลังสกัด Keyword ชุดที่ 8 (ข้อ 71 ถึง 80)...
# root_3_1_1_0 การดำเนินการ, หลักเกณฑ์ทั่วไป, กฎหมาย, ภาระผูกพัน, การออกตราสารหนี้
# root_3_1_1_1 ผู้ออกตราสารหนี้, ตราสารหนี้, กฎหมาย, บริษัทจำกัด, บริษัทมหาชนจำกัด, หุ้นกู้, ตั๋วเงิน, ผู้ลงทุนสถาบัน, PP10
# root_3_1_1_1_0 ผู้ออกตราสารหนี้, ตราสารหนี้, กฎหมาย, บริษัท, หุ้นกู้, ตั๋วเงิน
# root_3_1_1_2 ผู้ออกตราสารหนี้, ประวัติ, การเสนอขาย, ผู้ลงทุนสถาบัน, PP10, เจ้าหนี้, ปรับโครงสร้างหนี้, ผ่อนผัน
# root_3_1_1_2_0 ผู้ออกตราสารหนี้, ประวัติ, การเสนอขาย, ผู้ลงทุนสถาบัน
# root_3_1_2 การดำเนินการ, หลักเกณฑ์ทั่วไป, ผู้ออกตราสารหนี้, พันธบัตร, หุ้นกู้, ตั๋วเงิน, ผู้ลงทุนสถาบัน, PP10, เจ้าหนี้, ผ่อนผัน
# root_3_1_2_0 การดำเนินการ, หลักเกณฑ์ทั่วไป, ผู้ออกตราสารหนี้
# root_3_1_2_1 การดำเนินการ, หลักเกณฑ์ทั่วไป, ผู้ออกตราสารหนี้, พันธบัตร, หุ้นกู้, ตั๋วเงิน, ผู้ลงทุนสถาบัน, PP10, เจ้าหนี้, ผ่อนผัน
# root_3_1_2_1_0 พันธบัตร, หุ้นกู้, ตั๋วเงิน, ผู้ลงทุนสถาบัน, PP10, เจ้าหนี้, ผ่อนผัน
# root_3_1_2_2 การจดข้อจำกัดการโอน, ผู้ออกตราสารหนี้, ตราสารหนี้, การโอน, มรดก, ผู้ลงทุนสถาบัน
#   ✅ สำเร็จ!
#
# ⏳ กำลังสกัด Keyword ชุดที่ 9 (ข้อ 81 ถึง 90)...
# root_3_1_3 ผู้ออกหุ้นกู้, กิจการต่างประเทศ, หลักเกณฑ์ทั่วไป, คุณสมบัติอื่น, ผู้แทนผู้ถือหุ้นกู้, การเสนอขายหุ้นกู้, พันธบัตร, สกุลเงินบาท, กระทรวงการคลัง
# root_3_1_3_0 หลักเกณฑ์ทั่วไป, คุณสมบัติอื่น, ส่วนที่ 3
# root_3_1_3_1 กิจการต่างประเทศ, ผู้แทนในประเทศไทย, หน่วยงานกำกับดูแล, ตลาดทุน, หลักเกณฑ์การตรวจสอบ, สกุลเงินบาท, กระทรวงการคลัง
# root_3_1_3_1_0 กิจการต่างประเทศ, หลักเกณฑ์ทั่วไป, การเสนอขายหุ้นกู้, พันธบัตร
# root_3_1_3_2 ผู้ออกหุ้นกู้, ผู้แทนผู้ถือหุ้นกู้, กิจการต่างประเทศ, กิจการ ASEAN, สถาบันการเงิน, การให้ความช่วยเหลือ, การตรวจสอบ
# root_3_1_3_2_0 ผู้แทนผู้ถือหุ้นกู้, ลักษณะของผู้ออกหุ้นกู้, กิจการต่างประเทศ, กิจการ ASEAN
# root_3_2 ผู้ได้รับอนุญาต, หุ้นกู้, พันธบัตร, ผู้ลงทุนรายใหญ่พิเศษ, ผู้ลงทุนรายใหญ่, ตราสารหนี้, ภาคผนวก 1, ภาคผนวก 2
# root_3_2_0 ผู้ได้รับอนุญาต, หุ้นกู้, พันธบัตร, ผู้ลงทุนรายใหญ่พิเศษ, ผู้ลงทุนรายใหญ่, ตราสารหนี้
# root_3_2_0_0 ผู้ได้รับอนุญาต, หุ้นกู้, พันธบัตร, ผู้ลงทุนรายใหญ่พิเศษ, ผู้ลงทุนรายใหญ่, ภาค 4
# root_3_2_0_1 ผู้ได้รับอนุญาต, ตั๋วเงิน PP10, ผู้ลงทุนรายใหญ่พิเศษ, ผู้ลงทุนรายใหญ่, บริษัทหลักทรัพย์, ตราสารหนี้
#   ✅ สำเร็จ!
#
# ⏳ กำลังสกัด Keyword ชุดที่ 10 (ข้อ 91 ถึง 100)...
# root_3_2_0_2 ตราสารหนี้, ผู้ออก, ผู้ลงทุน, ภาคผนวก 1, เงื่อนไขที่กำหนด
# root_3_2_0_3 ตราสารหนี้ใหม่, ผู้ออก, ผู้ลงทุน, ภาคผนวก 2, เงื่อนไขเพิ่มเติม
# root_3_2_1 การออกและเสนอขายตราสารหนี้, ผู้ได้รับอนุญาต, ที่ปรึกษาทางการเงิน, ผู้ลงทุน
# root_3_2_1_0 การออกและเสนอขายตราสารหนี้, ผู้ได้รับอนุญาต, ที่ปรึกษาทางการเงิน
# root_3_2_1_1 ผู้ได้รับอนุญาต, ที่ปรึกษาทางการเงิน, ลักษณะการประกอบธุรกิจ, แผนธุรกิจ, ข้อมูลทางการเงิน
# root_3_2_1_1_0 ผู้ได้รับอนุญาต, ที่ปรึกษาทางการเงิน, ลักษณะการประกอบธุรกิจ, แผนธุรกิจ
# root_3_2_1_2 ผู้ได้รับอนุญาต, ระยะเวลาเสนอขาย, การขยายระยะเวลา, สำนักงาน
# root_3_2_1_3 การเสนอขายตราสารหนี้ในวงจำกัด, ผู้ลงทุนสถาบัน, หุ้นกู้, พันธบัตร, การโฆษณา
# root_3_2_1_3_0 การเสนอขายตราสารหนี้ในวงจำกัด, ผู้ลงทุนสถาบัน, หุ้นกู้, พันธบัตร
# root_3_2_1_3_2_0 การแจกจ่ายเอกสาร, ผู้ลงทุนสถาบัน, หุ้นกู้, พันธบัตร, การโอน
#   ✅ สำเร็จ!
#
# ⏳ กำลังสกัด Keyword ชุดที่ 11 (ข้อ 101 ถึง 110)...
# root_3_2_2 ตราสารหนี้, หุ้นกู้, พันธบัตร, ตั๋วเงิน, ผู้ลงทุนสถาบัน, อัตราดอกเบี้ย, มูลค่าไถ่ถอน, การโอนหุ้นกู้
# root_3_2_2_0 ส่วนนำ, ตราสารหนี้, หุ้นกู้, พันธบัตร, ตั๋วเงิน
# root_3_2_2_1 ตราสารหนี้, หุ้นกู้, พันธบัตร, ตั๋วเงิน, ผู้ลงทุนสถาบัน, อัตราดอกเบี้ย, มูลค่าไถ่ถอน, การโอนหุ้นกู้
# root_3_2_2_1_0 ตราสารหนี้, หุ้นกู้, พันธบัตร, ตั๋วเงิน
# root_3_2_2_2 พันธบัตร, หน่วยงานภาครัฐไทย, รัฐวิสาหกิจ, อันดับเครดิต, การเสนอขายพันธบัตร
# root_3_2_2_2_0 พันธบัตร, หน่วยงานภาครัฐไทย, การเสนอขายพันธบัตร
# root_3_2_2_3 หุ้นกู้ด้อยสิทธิ, ผู้ลงทุนสถาบัน, สิทธิของผู้ถือหุ้นกู้, การชำระหนี้, การพิทักษ์ทรัพย์
# root_3_2_2_3_0 หุ้นกู้ด้อยสิทธิ, ผู้ลงทุนสถาบัน, สิทธิของผู้ถือหุ้นกู้
# root_3_2_2_3_1_0 สิทธิของผู้ถือหุ้นกู้, การชำระหนี้, การพิทักษ์ทรัพย์
# root_3_2_2_3_2_0 ใบหุ้นกู้ด้อยสิทธิ, สาระสำคัญของหุ้นกู้ด้อยสิทธิ, การโอนหุ้นกู้ด้อยสิทธิ
#   ✅ สำเร็จ!
#
# ⏳ กำลังสกัด Keyword ชุดที่ 12 (ข้อ 111 ถึง 120)...
# root_3_2_2_4 ตั๋วเงิน, ผู้ได้รับอนุญาต, PP10, ผู้ลงทุนสถาบัน, FI, สถาบันคุ้มครองเงินฝาก, การเสนอขาย, หลักทรัพย์
# root_3_2_2_4_0 ตั๋วเงิน, ผู้ได้รับอนุญาต, การเสนอขาย, หลักทรัพย์
# root_3_2_2_5 PP10, หลักประกัน, การชำระหนี้, ตั๋วเงิน, ผู้ได้รับอนุญาต
# root_3_2_3 หุ้นกู้, ผู้ได้รับอนุญาต, สิทธิ, การโอน, พันธบัตร, การแก้ไขเพิ่มเติม
# root_3_2_3_0 หุ้นกู้, ผู้ได้รับอนุญาต, สิทธิ, การโอน
# root_3_2_3_1 หุ้นกู้, ผู้ได้รับอนุญาต, สิทธิ, มาตรา 42
# root_3_2_3_2 หุ้นกู้, การแก้ไขเพิ่มเติม, สิทธิ, หน้าที่, ความรับผิด, หลักประกัน, ผู้ได้รับอนุญาต
# root_3_2_3_3 หุ้นกู้, การโอน, ผู้ได้รับอนุญาต, นายทะเบียนหุ้นกู้, การลงทะเบียน
# root_3_2_3_4 พันธบัตร, ผู้ได้รับอนุญาต, สิทธิ, การโอน, การแก้ไขเพิ่มเติม
# root_3_2_4 การเสนอขาย, ตราสารหนี้, ผู้ได้รับอนุญาต, วัตถุประสงค์การใช้เงิน, การเปลี่ยนแปลงวัตถุประสงค์
#   ✅ สำเร็จ!
#
# ⏳ กำลังสกัด Keyword ชุดที่ 13 (ข้อ 121 ถึง 130)...
# root_3_2_4_0 การเสนอขายตราสารหนี้, ผู้ได้รับอนุญาต, วัตถุประสงค์การใช้เงิน
# root_3_2_4_1 ผู้ได้รับอนุญาต, การใช้เงินที่ได้รับ, วัตถุประสงค์การใช้เงิน, การเปลี่ยนแปลงวัตถุประสงค์
# root_3_2_5 การแจ้งข้อมูล, ผู้ได้รับอนุญาต, รายงานการไถ่ถอน, รายงานการใช้เงิน, ผู้แทนผู้ถือหุ้นกู้
# root_3_2_5_0 การแจ้งข้อมูล, ผู้ได้รับอนุญาต, รายงานการไถ่ถอน, รายงานการใช้เงิน
# root_3_2_5_1 ผู้ได้รับอนุญาต, รายงานการไถ่ถอน, รายงานการใช้เงิน, ผู้แทนผู้ถือหุ้นกู้, การเปลี่ยนแปลงผู้แทน
# root_3_2_5_1_0 ผู้ได้รับอนุญาต, รายงานการไถ่ถอน, รายงานการใช้เงิน, ผู้แทนผู้ถือหุ้นกู้
# root_3_2_5_2 ผู้ได้รับอนุญาต, หุ้นกู้, ผู้แทนผู้ถือหุ้นกู้, การผิดนัดชำระหนี้
# root_4 การเสนอขายตราสารหนี้, ผู้ลงทุนรายใหญ่พิเศษ, ผู้ลงทุนรายใหญ่, หลักเกณฑ์การอนุญาต
# root_4_0 การเสนอขายตราสารหนี้, ผู้ลงทุนรายใหญ่พิเศษ, ผู้ลงทุนรายใหญ่, หลักเกณฑ์การอนุญาต
# root_4_1 ผู้ขออนุญาต, หลักเกณฑ์การอนุญาต, การเปิดเผยข้อมูล, การจัดอันดับความน่าเชื่อถือ, คุณสมบัติอื่น ๆ
#   ✅ สำเร็จ!
#
# ⏳ กำลังสกัด Keyword ชุดที่ 14 (ข้อ 131 ถึง 140)...
# root_4_1_0 ผู้ขออนุญาต, ผู้ลงทุนรายใหญ่พิเศษ, ผู้ลงทุนรายใหญ่, หลักเกณฑ์ทั่วไป, การเปิดเผยข้อมูล, การดำเนินการตามกฎหมาย, ภาระผูกพัน, ฝ่ายบริหารจัดการ, การจัดอันดับความน่าเชื่อถือ, คุณสมบัติอื่น ๆ, ตราสารหนี้, ภาคผนวก 2
# root_4_1_0_0 ผู้ขออนุญาต, ผู้ลงทุนรายใหญ่พิเศษ, ผู้ลงทุนรายใหญ่, หลักเกณฑ์ทั่วไป, การเปิดเผยข้อมูล, การดำเนินการตามกฎหมาย, ภาระผูกพัน, ฝ่ายบริหารจัดการ, การจัดอันดับความน่าเชื่อถือ, คุณสมบัติอื่น ๆ, ตราสารหนี้, ภาคผนวก 2
# root_4_1_0_0_0 ผู้ขออนุญาต, ผู้ลงทุนรายใหญ่พิเศษ, ผู้ลงทุนรายใหญ่, หลักเกณฑ์ทั่วไป, การเปิดเผยข้อมูล, การดำเนินการตามกฎหมาย, ภาระผูกพัน, ฝ่ายบริหารจัดการ, การจัดอันดับความน่าเชื่อถือ
# root_4_1_0_1 หลักเกณฑ์ทั่วไป, ตราสารหนี้, บัญชีข้อกำหนด, ภาคผนวก 1, ผู้ลงทุนรายใหญ่พิเศษ, ผู้ลงทุนรายใหญ่
# root_4_1_1 หลักเกณฑ์ทั่วไป, การเปิดเผยข้อมูล, แบบแสดงรายการข้อมูล, งบการเงิน, งบการเงินรวม, ผู้สอบบัญชี, มาตรฐานการสอบบัญชี, มาตรฐานการรายงานทางการเงิน
# root_4_1_1_0 หลักเกณฑ์ทั่วไป, การเปิดเผยข้อมูล, แบบแสดงรายการข้อมูล, งบการเงิน, งบการเงินรวม
# root_4_1_1_1 แบบแสดงรายการข้อมูล, การเปิดเผยข้อมูล, คำขออนุญาต, โครงการ
# root_4_1_1_2 งบการเงิน, งบการเงินรวม, ผู้สอบบัญชี, มาตรฐานการสอบบัญชี, มาตรฐานการรายงานทางการเงิน, บริษัทที่ออกหลักทรัพย์, กรรมการ, ผู้บริหาร
# root_4_1_1_2_0 งบการเงิน, งบการเงินรวม, ผู้สอบบัญชี, มาตรฐานการสอบบัญชี
# root_4_1_1_2_3_0 รายงานการสอบบัญชี, ผู้สอบบัญชี, มาตรฐานการสอบบัญชี, บริษัทที่ออกหลักทรัพย์, กรรมการ, ผู้บริหาร
#   ✅ สำเร็จ!
#
# ⏳ กำลังสกัด Keyword ชุดที่ 15 (ข้อ 141 ถึง 150)...
# root_4_1_1_3 งบการเงิน, งบการเงินรวม, ผู้ขออนุญาต, กิจการต่างประเทศ, ธนาคารพาณิชย์ต่างประเทศ, หลักเกณฑ์การพิจารณา
# root_4_1_1_3_0 งบการเงิน, งบการเงินรวม, ผู้ขออนุญาต, หลักเกณฑ์การพิจารณา
# root_4_1_1_4 ผู้ขออนุญาต, การดำเนินการ, สำนักงาน, การผ่อนผัน, การค้างส่งงบการเงิน, การค้างส่งรายงาน
# root_4_1_1_4_0 ผู้ขออนุญาต, การดำเนินการ, สำนักงาน, การผ่อนผัน
# root_4_1_2 หลักเกณฑ์การดำเนินการ, กฎหมาย, ภาระผูกพัน, ผู้ขออนุญาต, การเสนอขายตราสารหนี้
# root_4_1_2_0 หลักเกณฑ์การดำเนินการ, กฎหมาย, ภาระผูกพัน
# root_4_1_2_1 ผู้ขออนุญาต, หลักเกณฑ์ในข้อ 19, หลักเกณฑ์ในข้อ 20
# root_4_1_2_2 ผู้ขออนุญาต, การผิดนัดชำระหนี้, ตราสารหนี้, ธนาคารพาณิชย์, บริษัทเงินทุน, บริษัทเครดิตฟองซิเอร์
# root_4_1_2_3 ผู้ขออนุญาต, การฝ่าฝืนหลักเกณฑ์, การเสนอขายหลักทรัพย์, การเปิดเผยข้อมูล, การรักษาสิทธิผู้ถือหุ้น, การหลอกลวง, การฉ้อโกง, การทุจริต
# root_4_1_2_3_0 ผู้ขออนุญาต, การฝ่าฝืนหลักเกณฑ์, การเสนอขายหลักทรัพย์, การเปิดเผยข้อมูล
#   ✅ สำเร็จ!
#
# ⏳ กำลังสกัด Keyword ชุดที่ 16 (ข้อ 151 ถึง 160)...
# root_4_1_2_3_1_0 ผู้ขออนุญาต, ระยะเวลา 5 ปี, วันยื่นคำขออนุญาต, ตราสารหนี้, ลักษณะผู้ขออนุญาต
# root_4_1_2_3_3_0 สิทธิของผู้ถือหุ้น, ผู้ถือหุ้น, บุคคล, ประโยชน์ทางการเงิน, บริษัท
# root_4_1_2_4 ข้อ 53, ผู้ขออนุญาต, ระบบงาน, ระบบการบริหารจัดการ, การควบคุมการดำเนินงาน, บริษัทจดทะเบียน
# root_4_1_2_4_0 ข้อ 54, ข้อ 53, ผู้ขออนุญาต
# root_4_1_3 ส่วนที่ 3, ฝ่ายบริหารจัดการ, กรรมการ, ผู้บริหาร, ระบบข้อมูล, รายชื่อกรรมการ, ผู้มีอำนาจควบคุม
# root_4_1_3_0 ส่วนที่ 3, ฝ่ายบริหารจัดการ
# root_4_1_3_1 ข้อ 55, กรรมการ, ผู้บริหาร, ระบบข้อมูล, รายชื่อกรรมการ, ธนาคารพาณิชย์ต่างประเทศ
# root_4_1_3_2 ข้อ 56, ผู้มีอำนาจควบคุม, ลักษณะขาดความน่าไว้วางใจ, กรรมการ, ผู้บริหาร
# root_4_1_4 ส่วนที่ 4, การจัดอันดับความน่าเชื่อถือ, หุ้นกู้, สถาบันจัดอันดับความน่าเชื่อถือ, ตราสารหนี้, ผู้ค้ำประกัน
# root_4_1_4_0 ส่วนที่ 4, การจัดอันดับความน่าเชื่อถือ
#   ✅ สำเร็จ!
#
# ⏳ กำลังสกัด Keyword ชุดที่ 17 (ข้อ 161 ถึง 170)...
# root_4_1_4_1 ผู้ได้รับอนุญาต, สถาบันจัดอันดับความน่าเชื่อถือ, ตราสารหนี้ระยะสั้น, ตราสารหนี้ระยะสั้นที่มีการค้ำประกัน, การค้ำประกันเต็มจำนวนที่มีผลบังคับ
# root_4_1_4_1_0 ผู้ได้รับอนุญาต, สถาบันจัดอันดับความน่าเชื่อถือ, ตราสารหนี้ระยะสั้น, ตราสารหนี้ระยะสั้นที่มีการค้ำประกัน
# root_4_1_4_2 ผู้ได้รับอนุญาต, สถาบันจัดอันดับความน่าเชื่อถือ, การยกเว้นการจัดอันดับความน่าเชื่อถือ, เหตุอันสมควร, การผ่อนผัน
# root_4_1_4_2_0 ผู้ได้รับอนุญาต, การยกเว้นการจัดอันดับความน่าเชื่อถือ, เหตุอันสมควร, การผ่อนผัน
# root_4_1_5 ผู้ขออนุญาต, กิจการต่างประเทศ, หลักเกณฑ์ทั่วไป, คุณสมบัติอื่น ๆ, ผู้แทนผู้ถือหุ้นกู้
# root_4_1_5_0 ผู้ขออนุญาต, กิจการต่างประเทศ, หลักเกณฑ์ทั่วไป, คุณสมบัติอื่น ๆ
# root_4_1_5_1 ผู้ขออนุญาต, กิจการต่างประเทศ, หลักเกณฑ์ทั่วไป, คุณสมบัติอื่น ๆ, ผู้แทนผู้ถือหุ้นกู้, หน่วยงานกำกับดูแลตลาดทุน
# root_4_1_5_1_0 ผู้ขออนุญาต, กิจการต่างประเทศ, หลักเกณฑ์ทั่วไป, คุณสมบัติอื่น ๆ, ผู้แทนผู้ถือหุ้นกู้
# root_4_1_5_2 ผู้ขออนุญาต, ผู้แทนผู้ถือหุ้นกู้, หลักเกณฑ์ในข้อ 24
# root_4_2 ผู้ขออนุญาต, วิธีการยื่น, การพิจารณาคำขออนุญาต, ตราสารหนี้, การขออนุญาตในลักษณะโครงการ, การขออนุญาตในลักษณะรายครั้ง
#   ✅ สำเร็จ!
#
# ⏳ กำลังสกัด Keyword ชุดที่ 18 (ข้อ 171 ถึง 180)...
# root_4_2_0 วิธีการยื่นคำขออนุญาต, การพิจารณาคำขออนุญาต, ตราสารหนี้, ผู้ขออนุญาต
# root_4_2_1 การขออนุญาตในลักษณะรายครั้ง, การขออนุญาตในลักษณะโครงการ, ตราสารหนี้ที่มีอันดับความน่าเชื่อถือ, หุ้นกู้ด้อยสิทธิ, หุ้นกู้ที่ครบกำหนดไถ่ถอนเมื่อเลิกบริษัท, หุ้นกู้เพื่อการแปลงสินทรัพย์เป็นหลักทรัพย์
# root_4_2_1_0 การขออนุญาต, ตราสารหนี้, ผู้ขออนุญาต, แบบแสดงรายการข้อมูลการเสนอขายตราสารหนี้
# root_4_2_1_2_0 การขออนุญาตในลักษณะโครงการ, ตราสารหนี้, ผู้ขออนุญาต, อันดับความน่าเชื่อถือ
# root_4_2_2 หุ้นกู้ที่มีอนุพันธ์แฝง, ผู้ค้าสัญญาซื้อขายล่วงหน้า, ธนาคารพาณิชย์, บริษัทเงินทุน, บริษัทเครดิตฟองซิเอร์
# root_4_2_2_0 หุ้นกู้ที่มีอนุพันธ์แฝง, ผู้ค้าสัญญาซื้อขายล่วงหน้า, ธนาคารพาณิชย์, บริษัทเงินทุน
# root_4_2_3 ผู้แทนผู้ถือหุ้นกู้, ผู้ขออนุญาต, ความเห็นชอบ, การแต่งตั้งผู้แทน
# root_4_2_4 ค่าธรรมเนียม, คำขออนุญาต, เอกสารหลักฐาน, การชำระค่าธรรมเนียม
# root_4_2_5 การพิจารณาคำขออนุญาต, ผลการพิจารณา, การขอผ่อนผัน, หลักเกณฑ์
# root_4_2_6 การเสนอขายตราสารหนี้, ลักษณะโครงการ, อายุโครงการ, มูลค่าและจำนวนครั้งที่เสนอขาย
#   ✅ สำเร็จ!
#
# ⏳ กำลังสกัด Keyword ชุดที่ 19 (ข้อ 181 ถึง 190)...
# root_4_2_7 หุ้นกู้แปลงสภาพ, หุ้นรองรับ, การอนุญาต
# root_4_2_8 การอนุญาต, ตราสารหนี้, การจัดอันดับความน่าเชื่อถือ, การระงับ
# root_4_3 เงื่อนไขภายหลังการอนุญาต, ผู้ได้รับอนุญาต, ตราสารหนี้
# root_4_3_0 เงื่อนไขภายหลังการอนุญาต, ส่วนนำ
# root_4_3_1 บททั่วไป, ผู้ได้รับอนุญาต, เงื่อนไขภายหลังการอนุญาต
# root_4_3_1_0 บททั่วไป, ส่วนนำ
# root_4_3_1_1 ผู้ได้รับอนุญาต, เงื่อนไขภายหลังการอนุญาต, ภาค 3
# root_4_3_1_2 ตราสารหนี้, ผู้ออก, การเสนอขาย, ภาคผนวก 2
# root_4_3_2 การเสนอขาย, บริษัทหลักทรัพย์, ผู้ให้บริการ
# root_4_3_2_0 การเสนอขาย, ส่วนนำ
#   ✅ สำเร็จ!
#
# ⏳ กำลังสกัด Keyword ชุดที่ 20 (ข้อ 191 ถึง 200)...
# root_4_3_2_1 ผู้ได้รับอนุญาต, บริษัทหลักทรัพย์, ตราสารหนี้, การซื้อขาย, การลงทุน, หลักเกณฑ์การให้บริการ
# root_4_3_3 ตราสารหนี้, ตั๋วเงิน, ธนาคารพาณิชย์, บริษัทเงินทุน, บริษัทเครดิตฟองซิเอร์, หลักประกัน, หุ้นกู้, พันธบัตร
# root_4_3_3_0 ตราสารหนี้, ลักษณะของตราสารหนี้, การออกและเสนอขายตั๋วเงิน
# root_4_3_3_1 ตั๋วเงิน, ธนาคารพาณิชย์, บริษัทเงินทุน, บริษัทเครดิตฟองซิเอร์, การออกและเสนอขายตั๋วเงิน, หลักประกัน
# root_4_3_3_2 หุ้นกู้มีประกัน, หลักประกัน, ทรัพย์สิน, การค้ำประกัน, นิติบุคคล, อสังหาริมทรัพย์, สิทธิการเช่า
# root_4_3_3_2_0 หุ้นกู้มีประกัน, หลักประกัน, ทรัพย์สิน, การค้ำประกัน, นิติบุคคล
# root_4_3_3_2_3_0 หลักประกัน, อสังหาริมทรัพย์, สิทธิการเช่า, การประเมินมูลค่า, บริษัทประเมินมูลค่าทรัพย์สิน
# root_4_3_4 ข้อกำหนดสิทธิ, หุ้นกู้, พันธบัตร, ผู้ออกตราสาร, ผู้มีอำนาจลงนาม, ตราสำคัญ
# root_4_3_4_0 ข้อกำหนดสิทธิ, หุ้นกู้, พันธบัตร, การเสนอขาย
# root_4_3_4_1 ข้อกำหนดสิทธิ, หุ้นกู้, พันธบัตร, ผู้ออกตราสาร, ผู้มีอำนาจลงนาม, ตราสำคัญ, การรับรอง
#   ✅ สำเร็จ!
#
# ⏳ กำลังสกัด Keyword ชุดที่ 21 (ข้อ 201 ถึง 210)...
# root_4_3_4_1_0 ผู้ได้รับอนุญาต, หุ้นกู้, พันธบัตร, สิทธิ, คู่สัญญา, ผู้ออกตราสาร
# root_4_3_4_2 การแก้ไขเพิ่มเติม, สิทธิ, หน้าที่, ความรับผิด, หลักประกัน, หุ้นกู้, พันธบัตร, ผู้ถือตราสาร
# root_4_3_5 ผู้แทนผู้ถือหุ้นกู้, สัญญา, ข้อกำหนดสิทธิ, มาตรา 43, คู่สัญญา, ผู้ออกหุ้นกู้
# root_4_3_5_0 ผู้แทนผู้ถือหุ้นกู้, สัญญา, ข้อกำหนดสิทธิ, มาตรา 43, คู่สัญญา, ผู้ออกหุ้นกู้
# root_4_3_5_1 ผู้แทนผู้ถือหุ้นกู้, สัญญา, ข้อกำหนดสิทธิ, มาตรา 43, คู่สัญญา, ผู้ออกหุ้นกู้, อัตราค่าตอบแทน, วิธีการจ่ายคืนเงินทดรอง
# root_4_3_5_1_0 ผู้แทนผู้ถือหุ้นกู้, สัญญา, ข้อกำหนดสิทธิ, มาตรา 43, คู่สัญญา, ผู้ออกหุ้นกู้
# root_5 หุ้นกู้แปลงสภาพ, บุคคลที่มีลักษณะเฉพาะ, อนุพันธ์แฝง, สถาบันการเงิน, อัตราดอกเบี้ย, หุ้นรองรับ
# root_5_0 หุ้นกู้แปลงสภาพ, บุคคลที่มีลักษณะเฉพาะ, อนุพันธ์แฝง, สถาบันการเงิน, อัตราดอกเบี้ย, หุ้นรองรับ
# root_5_1 หุ้นกู้แปลงสภาพ, บุคคลที่มีลักษณะเฉพาะ, อนุพันธ์แฝง, สถาบันการเงิน, อัตราดอกเบี้ย, หุ้นรองรับ, มูลค่าผลตอบแทน, ราคาแปลงสภาพ
# root_5_1_0 หุ้นกู้แปลงสภาพ, บุคคลที่มีลักษณะเฉพาะ, อนุพันธ์แฝง, สถาบันการเงิน, อัตราดอกเบี้ย, หุ้นรองรับ, มูลค่าผลตอบแทน, ราคาแปลงสภาพ
#   ✅ สำเร็จ!
#
# ⏳ กำลังสกัด Keyword ชุดที่ 22 (ข้อ 211 ถึง 220)...
# root_5_1_2_0 เงื่อนไขครบถ้วน, ผู้ถือหุ้น, บริษัทจดทะเบียน
# root_5_2 หุ้นกู้แปลงสภาพ, บริษัทมหาชนจำกัด, มติที่ประชุมผู้ถือหุ้น, สัดส่วนการถือหุ้น
# root_5_2_0 หุ้นกู้แปลงสภาพ, บริษัทจดทะเบียน, บริษัทมหาชนจำกัด, มาตรา 56
# root_5_2_2_0 ผู้ถือหุ้น, บริษัท, สัดส่วนการถือหุ้น, หุ้นกู้แปลงสภาพ
# root_5_3 บริษัท, อนุญาต, เงื่อนไขภายหลังการอนุญาต, หุ้นกู้แปลงสภาพ
# root_5_3_0 บริษัท, อนุญาต, เงื่อนไขภายหลังการอนุญาต, หุ้นกู้แปลงสภาพ
# root_5_4 หุ้นกู้แปลงสภาพ, บุคคลที่เป็นเจ้าหนี้, บริษัทมหาชนจำกัด, แผนฟื้นฟูกิจการ
# root_5_5 คำขออนุญาต, ตราสารหนี้, บุคคลในวงจำกัด, ผู้ลงทุนสถาบัน
# root_5_5_0 คำขออนุญาต, ตราสารหนี้, บุคคลในวงจำกัด, ผู้ลงทุนสถาบัน
# root_5_6 สำนักงาน, อนุญาต, ผู้ลงทุนสถาบัน, ผู้ลงทุนรายใหญ่พิเศษ
#   ✅ สำเร็จ!
#
# ⏳ กำลังสกัด Keyword ชุดที่ 23 (ข้อ 221 ถึง 222)...
# root_5_7 ประกาศ, ข้อ 81, การอ้างอิง, ประกาศฉบับอื่น, การกำกับหลักทรัพย์และตลาดหลักทรัพย์
# root_5_8 สำนักงานคณะกรรมการกำกับหลักทรัพย์และตลาดหลักทรัพย์, ประกาศ, คำสั่ง, หนังสือเวียน, บทเฉพาะกาล, ผู้ลงทุน, หลักทรัพย์และตลาดหลักทรัพย์
#   ✅ สำเร็จ!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 139
#     136 with open(SEC_W_KW_PATH, 'w', encoding='utf-8') as f:
#     137     json.dump(reg_data, f, ensure_ascii=False, indent=4)
# --> 139 print(f"\n🎉 สำเร็จ! บันทึกไฟล์ Tree แบบ Fast-Batch (จาก Raw Text) ลงใน '{output_filename}' เรียบร้อยแล้ว!\n")
#
# NameError: name 'output_filename' is not defined
